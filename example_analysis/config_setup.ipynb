# %% [markdown]
# ## Imports

# %%
import re
from pathlib import Path

import pandas as pd

# %% [markdown]
# ## Set parameters to find samples

# %%
# save path for sample dataframes
SBS_SAMPLES_DF_FP = Path('config/sbs_samples.tsv')
PHENOTYPE_SAMPLES_DF_FP = Path('config/phenotype_samples.tsv')

# directories with SBS/phenotype sample nd2 files
SBS_DATA_FP = Path('data/input/sbs/')
PHENOTYPE_DATA_FP = Path('data/input/phenotype/')

# patterns to match SBS/phenotype sample nd2 files
SBS_SAMPLE_PATTERN = r"C(\d+)_Wells-([A-Z]\d+)_Points-(\d{3})__Channel"
PHENOTYPE_SAMPLE_PATTERN = r"Wells-([A-Z]\d+)_Points-(\d{3})__Channel"

""""
Example nd2 file names:
SBS: P001_SBS_10x_C9_Wells-A1_Points-100__Channel_Cy7,Cy5,AF594,Cy3_SBS,DAPI_SBS.nd2
Phenotype: P001_Pheno_20x_Wells-A1_Points-001__Channel_AF750,Cy3,GFP,DAPI.nd2
"""
# Out:
# '"\nExample nd2 file names:\nSBS: P001_SBS_10x_C9_Wells-A1_Points-100__Channel_Cy7,Cy5,AF594,Cy3_SBS,DAPI_SBS.nd2\nPhenotype: P001_Pheno_20x_Wells-A1_Points-001__Channel_AF750,Cy3,GFP,DAPI.nd2\n'

# %%
# List to store file information
sbs_data = []

# Iterate over files and extract information
for file in SBS_DATA_FP.iterdir():
    match = re.search(SBS_SAMPLE_PATTERN, file.name)
    if match:
        cycle = int(match.group(1))
        well = match.group(2)
        tile = int(match.group(3))
        
        sbs_data.append({"sample_fp": str(file), "well": well, "tile": tile, "cycle": cycle})

# Create a DataFrame and sort by well, tile, and cycle
sbs_samples = pd.DataFrame(sbs_data)
sbs_samples = sbs_samples.sort_values(by=["well", "tile", "cycle"])
sbs_samples = sbs_samples.reset_index(drop=True)

sbs_samples.to_csv(SBS_SAMPLES_DF_FP, sep="\t", index=False)
sbs_samples
# Out:
#                                             sample_fp well  tile  cycle
# 0   data/input/sbs/P001_SBS_10x_C1_Wells-A1_Points...   A1     1      1
# 1   data/input/sbs/P001_SBS_10x_C2_Wells-A1_Points...   A1     1      2
# 2   data/input/sbs/P001_SBS_10x_C3_Wells-A1_Points...   A1     1      3
# 3   data/input/sbs/P001_SBS_10x_C4_Wells-A1_Points...   A1     1      4
# 4   data/input/sbs/P001_SBS_10x_C5_Wells-A1_Points...   A1     1      5
# 5   data/input/sbs/P001_SBS_10x_C6_Wells-A1_Points...   A1     1      6
# 6   data/input/sbs/P001_SBS_10x_C7_Wells-A1_Points...   A1     1      7
# 7   data/input/sbs/P001_SBS_10x_C8_Wells-A1_Points...   A1     1      8
# 8   data/input/sbs/P001_SBS_10x_C9_Wells-A1_Points...   A1     1      9
# 9   data/input/sbs/P001_SBS_10x_C10_Wells-A1_Point...   A1     1     10
# 10  data/input/sbs/P001_SBS_10x_C11_Wells-A1_Point...   A1     1     11
# 11  data/input/sbs/P001_SBS_10x_C1_Wells-A1_Points...   A1   100      1
# 12  data/input/sbs/P001_SBS_10x_C2_Wells-A1_Points...   A1   100      2
# 13  data/input/sbs/P001_SBS_10x_C3_Wells-A1_Points...   A1   100      3
# 14  data/input/sbs/P001_SBS_10x_C4_Wells-A1_Points...   A1   100      4
# 15  data/input/sbs/P001_SBS_10x_C5_Wells-A1_Points...   A1   100      5
# 16  data/input/sbs/P001_SBS_10x_C6_Wells-A1_Points...   A1   100      6
# 17  data/input/sbs/P001_SBS_10x_C7_Wells-A1_Points...   A1   100      7
# 18  data/input/sbs/P001_SBS_10x_C8_Wells-A1_Points...   A1   100      8
# 19  data/input/sbs/P001_SBS_10x_C9_Wells-A1_Points...   A1   100      9
# 20  data/input/sbs/P001_SBS_10x_C10_Wells-A1_Point...   A1   100     10
# 21  data/input/sbs/P001_SBS_10x_C11_Wells-A1_Point...   A1   100     11
# 22  data/input/sbs/P001_SBS_10x_C1_Wells-A2_Points...   A2     1      1
# 23  data/input/sbs/P001_SBS_10x_C2_Wells-A2_Points...   A2     1      2
# 24  data/input/sbs/P001_SBS_10x_C3_Wells-A2_Points...   A2     1      3
# 25  data/input/sbs/P001_SBS_10x_C4_Wells-A2_Points...   A2     1      4
# 26  data/input/sbs/P001_SBS_10x_C5_Wells-A2_Points...   A2     1      5
# 27  data/input/sbs/P001_SBS_10x_C6_Wells-A2_Points...   A2     1      6
# 28  data/input/sbs/P001_SBS_10x_C7_Wells-A2_Points...   A2     1      7
# 29  data/input/sbs/P001_SBS_10x_C8_Wells-A2_Points...   A2     1      8
# 30  data/input/sbs/P001_SBS_10x_C9_Wells-A2_Points...   A2     1      9
# 31  data/input/sbs/P001_SBS_10x_C10_Wells-A2_Point...   A2     1     10
# 32  data/input/sbs/P001_SBS_10x_C11_Wells-A2_Point...   A2     1     11
# 33  data/input/sbs/P001_SBS_10x_C1_Wells-A2_Points...   A2   100      1
# 34  data/input/sbs/P001_SBS_10x_C2_Wells-A2_Points...   A2   100      2
# 35  data/input/sbs/P001_SBS_10x_C3_Wells-A2_Points...   A2   100      3
# 36  data/input/sbs/P001_SBS_10x_C4_Wells-A2_Points...   A2   100      4
# 37  data/input/sbs/P001_SBS_10x_C5_Wells-A2_Points...   A2   100      5
# 38  data/input/sbs/P001_SBS_10x_C6_Wells-A2_Points...   A2   100      6
# 39  data/input/sbs/P001_SBS_10x_C7_Wells-A2_Points...   A2   100      7
# 40  data/input/sbs/P001_SBS_10x_C8_Wells-A2_Points...   A2   100      8
# 41  data/input/sbs/P001_SBS_10x_C9_Wells-A2_Points...   A2   100      9
# 42  data/input/sbs/P001_SBS_10x_C10_Wells-A2_Point...   A2   100     10
# 43  data/input/sbs/P001_SBS_10x_C11_Wells-A2_Point...   A2   100     11

# %%
# List to store file information
phenotype_data = []

# Iterate over files and extract information
for file in PHENOTYPE_DATA_FP.iterdir():
    match = re.search(PHENOTYPE_SAMPLE_PATTERN, file.name)
    if match:
        well = match.group(1)
        tile = int(match.group(2))
        
        phenotype_data.append({"sample_fp": str(file), "well": well, "tile": tile})

# Create a DataFrame and sort by well, tile, and cycle
phenotype_samples = pd.DataFrame(phenotype_data)
phenotype_samples = phenotype_samples.sort_values(by=["well", "tile"])
phenotype_samples = phenotype_samples.reset_index(drop=True)

phenotype_samples.to_csv(PHENOTYPE_SAMPLES_DF_FP, sep="\t", index=False)
phenotype_samples
# Out:
#                                            sample_fp well  tile
# 0  data/input/phenotype/P001_Pheno_20x_Wells-A1_P...   A1     1
# 1  data/input/phenotype/P001_Pheno_20x_Wells-A1_P...   A1   100
# 2  data/input/phenotype/P001_Pheno_20x_Wells-A2_P...   A2     1
# 3  data/input/phenotype/P001_Pheno_20x_Wells-A2_P...   A2   100
